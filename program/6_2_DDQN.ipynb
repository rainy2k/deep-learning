# %% [markdown]
# ## 6.2 PyTorchでDDQN

# %%
# パッケージのimport
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 動画の描画関数の宣言
# 参考URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole_DDQN.mp4')  # 動画のファイル名と保存です
    display(display_animation(anim, default_mode='loop'))

# %%
# namedtupleを生成
from collections import namedtuple

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
# 定数の設定
ENV = 'CartPole-v0'  # 使用する課題名
GAMMA = 0.99  # 時間割引率
MAX_STEPS = 200  # 1試行のstep数
NUM_EPISODES = 500  # 最大試行回数

# %%
# 経験を保存するメモリクラスを定義します


class ReplayMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  # メモリの最大長さ
        self.memory = []  # 経験を保存する変数
        self.index = 0  # 保存するindexを示す変数

    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)をメモリに保存する'''

        if len(self.memory) < self.capacity:
            self.memory.append(None)  # メモリが満タンでないときは足す

        # namedtupleのTransitionを使用し、値とフィールド名をペアにして保存します
        self.memory[self.index] = Transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity  # 保存するindexを1つずらす

    def sample(self, batch_size):
        '''batch_size分だけ、ランダムに保存内容を取り出す'''
        return random.sample(self.memory, batch_size)

    def __len__(self):
        '''関数lenに対して、現在の変数memoryの長さを返す'''
        return len(self.memory)

# %%
# ディープ・ニューラルネットワークの構築
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):

    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_out)

    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        output = self.fc3(h2)
        return output

# %%
# エージェントが持つ脳となるクラスです、DDQNを実行します

import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000


class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得

        # 経験を記憶するメモリオブジェクトを生成
        self.memory = ReplayMemory(CAPACITY)

        # ニューラルネットワークを構築
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)  # Netクラスを使用
        self.target_q_network = Net(n_in, n_mid, n_out)  # Netクラスを使用
        print(self.main_q_network)  # ネットワークの形を出力

        # 最適化手法の設定
        self.optimizer = optim.Adam(
            self.main_q_network.parameters(), lr=0.0001)

    def replay(self):
        '''Experience Replayでネットワークの結合パラメータを学習'''

        # 1. メモリサイズの確認
        if len(self.memory) < BATCH_SIZE:
            return

        # 2. ミニバッチの作成
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()

        # 3. 教師信号となるQ(s_t, a_t)値を求める
        self.expected_state_action_values = self.get_expected_state_action_values()

        # 4. 結合パラメータの更新
        self.update_main_q_network()

    def decide_action(self, state, episode):
        '''現在の状態に応じて、行動を決定する'''
        # ε-greedy法で徐々に最適行動のみを採用する
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()  # ネットワークを推論モードに切り替える
            with torch.no_grad():
                print("test1 : ", self.main_q_network(state))
                print("test2 : ", self.main_q_network(state).max(1)[1])
                print("test3 : ", self.main_q_network(state).max(1)[1].view(1, 1))
                action = self.main_q_network(state).max(1)[1].view(1, 1)
            # ネットワークの出力の最大値のindexを取り出します = max(1)[1]
            # .view(1,1)は[torch.LongTensor of size 1]　を size 1x1 に変換します

        else:
            # 0,1の行動をランダムに返す
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 0,1の行動をランダムに返す
            # actionは[torch.LongTensor of size 1x1]の形になります

        return action

    def make_minibatch(self):
        '''2. ミニバッチの作成'''

        # 2.1 メモリからミニバッチ分のデータを取り出す
        transitions = self.memory.sample(BATCH_SIZE)

        # 2.2 各変数をミニバッチに対応する形に変形
        # transitionsは1stepごとの(state, action, state_next, reward)が、BATCH_SIZE分格納されている
        # つまり、(state, action, state_next, reward)×BATCH_SIZE
        # これをミニバッチにしたい。つまり
        # (state×BATCH_SIZE, action×BATCH_SIZE, state_next×BATCH_SIZE, reward×BATCH_SIZE)にする
        batch = Transition(*zip(*transitions))

        # 2.3 各変数の要素をミニバッチに対応する形に変形し、ネットワークで扱えるようVariableにする
        # 例えばstateの場合、[torch.FloatTensor of size 1x4]がBATCH_SIZE分並んでいるのですが、
        # それを torch.FloatTensor of size BATCH_SIZEx4 に変換します
        # 状態、行動、報酬、non_finalの状態のミニバッチのVariableを作成
        # catはConcatenates（結合）のことです。
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''3. 教師信号となるQ(s_t, a_t)値を求める'''

        # 3.1 ネットワークを推論モードに切り替える
        self.main_q_network.eval()
        self.target_q_network.eval()

        # 3.2 ネットワークが出力したQ(s_t, a_t)を求める
        # self.model(state_batch)は、右左の両方のQ値を出力しており
        # [torch.FloatTensor of size BATCH_SIZEx2]になっている。
        # ここから実行したアクションa_tに対応するQ値を求めるため、action_batchで行った行動a_tが右か左かのindexを求め
        # それに対応するQ値をgatherでひっぱり出す。
        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)

        # 3.3 max{Q(s_t+1, a)}値を求める。ただし次の状態があるかに注意。
        # cartpoleがdoneになっておらず、next_stateがあるかをチェックするインデックスマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))
        # まずは全部0にしておく
        next_state_values = torch.zeros(BATCH_SIZE)

        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)
        # 次の状態での最大Q値の行動a_mをMain Q-Networkから求める
        # 最後の[1]で行動に対応したindexが返る
        a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(1)[1]

        # 次の状態があるものだけにフィルターし、size 32を32×1へ
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        # 次の状態があるindexの、行動a_mのQ値をtarget Q-Networkから求める
        # detach()で取り出す
        # squeeze()でsize[minibatch×1]を[minibatch]に。
        next_state_values[non_final_mask] = self.target_q_network(
            self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()
        # 3.4 教師となるQ(s_t, a_t)値を、Q学習の式から求める
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values
        return expected_state_action_values

    def update_main_q_network(self):
        '''4. 結合パラメータの更新'''

        # 4.1 ネットワークを訓練モードに切り替える
        self.main_q_network.train()

        # 4.2 損失関数を計算する（smooth_l1_lossはHuberloss）
        # expected_state_action_valuesは
        # sizeが[minbatch]になっているので、unsqueezeで[minibatch x 1]へ
        print("loss1",self.state_action_values.shape,"loss2",self.expected_state_action_values.unsqueeze(1).shape)
        loss = F.smooth_l1_loss(self.state_action_values,
                                self.expected_state_action_values.unsqueeze(1))

        # 4.3 結合パラメータを更新する
        self.optimizer.zero_grad()  # 勾配をリセット
        loss.backward()  # バックプロパゲーションを計算
        self.optimizer.step()  # 結合パラメータを更新

    def update_target_q_network(self):  # DDQNで追加
        '''Target Q-NetworkをMainと同じにする'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %%
# CartPoleで動くエージェントクラスです、棒付き台車そのものになります


class Agent:
    def __init__(self, num_states, num_actions):
        '''課題の状態と行動の数を設定する'''
        self.brain = Brain(num_states, num_actions)  # エージェントが行動を決定するための頭脳を生成

    def update_q_function(self):
        '''Q関数を更新する'''
        self.brain.replay()

    def get_action(self, state, episode):
        '''行動を決定する'''
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        '''memoryオブジェクトに、state, action, state_next, rewardの内容を保存する'''
        self.brain.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        '''Target Q-NetworkをMain Q-Networkと同じに更新'''
        self.brain.update_target_q_network()

# %%
# CartPoleを実行する環境のクラスです


class Environment:

    def __init__(self):
        self.env = gym.make(ENV)  # 実行する課題を設定
        num_states = self.env.observation_space.shape[0]  # 課題の状態と行動の数を設定
        num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の2を取得
        # 環境内で行動するAgentを生成
        self.agent = Agent(num_states, num_actions)

    def run(self):
        '''実行'''
        episode_10_list = np.zeros(10)  # 10試行分の立ち続けたstep数を格納し、平均ステップ数を出力に利用
        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        episode_final = False  # 最後の試行フラグ
        frames = []  # 最後の試行を動画にするために画像を格納する変数

        for episode in range(NUM_EPISODES):  # 試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化

            state = observation  # 観測をそのまま状態sとして使用
            state = torch.from_numpy(state).type(
                torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
            state = torch.unsqueeze(state, 0)  # size 4をsize 1x4に変換
            print("obs",observation,"state",state)
            for step in range(MAX_STEPS):  # 1エピソードのループ
                
                # 動画描画をコメントアウトしています
                #if episode_final is True:  # 最終試行ではframesに各時刻の画像を追加していく
                    # frames.append(self.env.render(mode='rgb_array'))
                    
                action = self.agent.get_action(state, episode)  # 行動を求める

                # 行動a_tの実行により、s_{t+1}とdoneフラグを求める
                # actionから.item()を指定して、中身を取り出す
                observation_next, _, done, _ = self.env.step(action.item())  # rewardとinfoは使わないので_にする

                # 報酬を与える。さらにepisodeの終了評価と、state_nextを設定する
                if done:  # ステップ数が200経過するか、一定角度以上傾くとdoneはtrueになる
                    state_next = None  # 次の状態はないので、Noneを格納
                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))
                    if step < 195:
                        reward = torch.FloatTensor( [-1.0])  # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0  # 連続成功記録をリセット
                    else:
                        reward = torch.FloatTensor([1.0])  # 立ったまま終了時は報酬1を与える
                        complete_episodes = complete_episodes + 1  # 連続記録を更新
                else:
                    reward = torch.FloatTensor([0.0])  # 普段は報酬0
                    state_next = observation_next  # 観測をそのまま状態とする
                    state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
                    state_next = torch.unsqueeze(state_next, 0)  # size 4をsize 1x4に変換

                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)

                # Experience ReplayでQ関数を更新する
                self.agent.update_q_function()

                # 観測の更新
                state = state_next

                # 終了時の処理
                if done:
                    print('%d Episode: Finished after %d steps：10試行の平均step数 = %.1lf' % (
                        episode, step + 1, episode_10_list.mean()))
                    
                    # DDQNで追加、2試行に1度、Target Q-NetworkをMainと同じにコピーする
                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break
                    
                    
            if episode_final is True:
                # 動画描画をコメントアウトしています
                # 動画を保存と描画
                #display_frames_as_gif(frames)
                break

            # 10連続で200step経ち続けたら成功
            if complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
# main クラス
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# obs [ 0.0205132   0.02702758 -0.04754699 -0.04772002] state tensor([[ 0.0205,  0.0270, -0.0475, -0.0477]])
# test1 :  tensor([[0.0804, 0.1678]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1220, 0.1285]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1187, 0.1255]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1160, 0.1261]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# 0 Episode: Finished after 9 steps：10試行の平均step数 = 0.9
# obs [ 0.0091262  -0.01498178 -0.01567463 -0.02385895] state tensor([[ 0.0091, -0.0150, -0.0157, -0.0239]])
# test1 :  tensor([[0.0823, 0.1681]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1051, 0.1478]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1218, 0.1304]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1221, 0.1256]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.0951, 0.1257]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.0925, 0.1356]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.0896, 0.1416]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# 1 Episode: Finished after 9 steps：10試行の平均step数 = 1.8
# obs [ 0.04864171  0.03343368  0.03130755 -0.04979486] state tensor([[ 0.0486,  0.0334,  0.0313, -0.0498]])
# test1 :  tensor([[0.1206, 0.1274]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1187, 0.1268]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1213, 0.1217]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1081, 0.1222]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.0978, 0.1221]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.0943, 0.1333]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.0909, 0.1391]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# 2 Episode: Finished after 11 steps：10試行の平均step数 = 2.9
# obs [0.03704635 0.00236479 0.0073604  0.00092725] state tensor([[0.0370, 0.0024, 0.0074, 0.0009]])
# test1 :  tensor([[0.1045, 0.1458]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# test1 :  tensor([[0.1201, 0.1290]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1220, 0.1225]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1218, 0.1198]])
# test2 :
# /var/folders/jm/3cgjkcw943s630kp7txh0rpw0000gq/T/ipykernel_5216/3076239057.py:118: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:30.)
#   a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(1)[1]
# /var/folders/jm/3cgjkcw943s630kp7txh0rpw0000gq/T/ipykernel_5216/3076239057.py:121: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:30.)
#   a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)
# /var/folders/jm/3cgjkcw943s630kp7txh0rpw0000gq/T/ipykernel_5216/3076239057.py:126: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:30.)
#   next_state_values[non_final_mask] = self.target_q_network(
# tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1168, 0.1250]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1212, 0.1176]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1165, 0.1222]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1196, 0.1162]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1152, 0.1202]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1160, 0.1156]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1135, 0.1188]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1114, 0.1180]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 3 Episode: Finished after 15 steps：10試行の平均step数 = 4.4
# obs [-0.03323605  0.0296833   0.04070104  0.00427101] state tensor([[-0.0332,  0.0297,  0.0407,  0.0043]])
# test1 :  tensor([[0.0932, 0.1509]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1140, 0.1319]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1250, 0.1176]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1102, 0.1319]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1244, 0.1094]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1250, 0.1126]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1031, 0.1308]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1239, 0.1108]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1227, 0.1092]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1006, 0.1274]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1216, 0.1075]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1002, 0.1253]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1213, 0.1053]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1011, 0.1204]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1202, 0.1017]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1037, 0.1164]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1074, 0.0979]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 4 Episode: Finished after 24 steps：10試行の平均step数 = 6.8
# obs [-0.01912529  0.01888251 -0.04025441 -0.03532577] state tensor([[-0.0191,  0.0189, -0.0403, -0.0353]])
# test1 :  tensor([[0.0883, 0.1373]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1096, 0.1171]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1256, 0.1001]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1079, 0.1159]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1246, 0.0982]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1066, 0.1142]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1226, 0.0972]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1067, 0.1115]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1202, 0.0964]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1075, 0.1082]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1172, 0.0962]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1087, 0.1049]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0895, 0.1220]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1085, 0.1042]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0941, 0.1172]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1071, 0.1034]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 5 Episode: Finished after 16 steps：10試行の平均step数 = 8.4
# obs [-0.00404961 -0.01971108  0.01434606  0.04088389] state tensor([[-0.0040, -0.0197,  0.0143,  0.0409]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1008, 0.1126]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1160, 0.0954]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0966, 0.1128]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1136, 0.0943]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0930, 0.1126]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1111, 0.0935]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0899, 0.1121]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1091, 0.0922]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0875, 0.1112]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1075, 0.0906]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0855, 0.1100]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1061, 0.0889]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0847, 0.1083]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1050, 0.0872]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0851, 0.1056]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1029, 0.0860]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0667, 0.1207]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0892, 0.0987]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0975, 0.0848]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0904, 0.0951]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0937, 0.0847]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0901, 0.0927]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 6 Episode: Finished after 24 steps：10試行の平均step数 = 10.8
# obs [0.01187553 0.04856098 0.00889681 0.00359874] state tensor([[0.0119, 0.0486, 0.0089, 0.0036]])
# test1 :  tensor([[0.0715, 0.1214]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0886, 0.1038]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1026, 0.0858]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0850, 0.1039]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.1015, 0.0846]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0819, 0.1033]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0998, 0.0832]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0793, 0.1022]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0984, 0.0816]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0771, 0.1006]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0974, 0.0797]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0964, 0.0771]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0757, 0.0951]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0942, 0.0753]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0763, 0.0911]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0910, 0.0738]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0774, 0.0862]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0872, 0.0724]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0790, 0.0807]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 7 Episode: Finished after 21 steps：10試行の平均step数 = 12.9
# obs [ 0.00766358  0.01001354 -0.00814672  0.03179757] state tensor([[ 0.0077,  0.0100, -0.0081,  0.0318]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0774, 0.0980]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0940, 0.0784]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0741, 0.0972]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0921, 0.0768]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0715, 0.0958]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0906, 0.0752]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0691, 0.0942]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0893, 0.0733]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0673, 0.0922]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0838, 0.0676]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0847, 0.0694]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0657, 0.0856]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0815, 0.0681]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0673, 0.0812]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0779, 0.0671]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0692, 0.0761]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0736, 0.0665]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 8 Episode: Finished after 19 steps：10試行の平均step数 = 14.8
# obs [-0.00368021  0.01486787  0.01586904 -0.03455672] state tensor([[-0.0037,  0.0149,  0.0159, -0.0346]])
# test1 :  tensor([[0.0603, 0.1048]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0760, 0.0886]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0879, 0.0727]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0718, 0.0889]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0868, 0.0712]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0682, 0.0885]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0851, 0.0696]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0834, 0.0680]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0631, 0.0855]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0816, 0.0662]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0620, 0.0827]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0792, 0.0642]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0615, 0.0791]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0760, 0.0623]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0619, 0.0749]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0725, 0.0606]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0629, 0.0699]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0681, 0.0595]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0627, 0.0662]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0634, 0.0585]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 9 Episode: Finished after 21 steps：10試行の平均step数 = 16.9
# obs [ 0.02468256  0.01293746 -0.01848466 -0.02128555] state tensor([[ 0.0247,  0.0129, -0.0185, -0.0213]])
# test1 :  tensor([[0.0489, 0.0964]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0633, 0.0795]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0779, 0.0626]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0597, 0.0782]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0758, 0.0606]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0566, 0.0767]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0736, 0.0586]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0551, 0.0741]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0713, 0.0566]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0545, 0.0711]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0679, 0.0551]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0545, 0.0674]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0643, 0.0534]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0552, 0.0623]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0599, 0.0520]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0550, 0.0582]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0547, 0.0507]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 10 Episode: Finished after 17 steps：10試行の平均step数 = 17.7
# obs [ 0.01920706  0.03540776 -0.04176047  0.03110448] state tensor([[ 0.0192,  0.0354, -0.0418,  0.0311]])
# test1 :  tensor([[0.0410, 0.0939]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0700, 0.0559]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0492, 0.0730]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0678, 0.0535]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0464, 0.0704]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0660, 0.0506]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0448, 0.0670]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0630, 0.0480]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0444, 0.0627]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0588, 0.0461]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0443, 0.0576]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0539, 0.0441]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0447, 0.0514]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0481, 0.0426]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0425, 0.0473]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 11 Episode: Finished after 16 steps：10試行の平均step数 = 18.4
# obs [ 0.02626284  0.03447737 -0.04674995  0.02617041] state tensor([[ 0.0263,  0.0345, -0.0467,  0.0262]])
# test1 :  tensor([[0.0328, 0.0839]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0430, 0.0657]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0587, 0.0474]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0399, 0.0634]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0563, 0.0446]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0372, 0.0607]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0537, 0.0420]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0357, 0.0573]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0504, 0.0398]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0351, 0.0528]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0464, 0.0379]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0350, 0.0474]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0419, 0.0361]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0358, 0.0413]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0368, 0.0346]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# 12 Episode: Finished after 15 steps：10試行の平均step数 = 18.8
# obs [ 0.03635658  0.01654655  0.01889091 -0.03198024] state tensor([[ 0.0364,  0.0165,  0.0189, -0.0320]])
# test1 :  tensor([[0.0313, 0.0701]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0448, 0.0557]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0545, 0.0457]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0404, 0.0556]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0525, 0.0438]])
# test2 :  tensor([0])
# test3 :  tensor([[0]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# test1 :  tensor([[0.0368, 0.0549]])
# test2 :  tensor([1])
# test3 :  tensor([[1]])
# loss1 torch.Size([32, 1]) loss2 torch.Size([32, 1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/jm/3cgjkcw943s630kp7txh0rpw0000gq/T/ipykernel_5216/3548934082.py in <module>
#       1 # main クラス
#       2 cartpole_env = Environment()
# ----> 3 cartpole_env.run()
#
# /var/folders/jm/3cgjkcw943s630kp7txh0rpw0000gq/T/ipykernel_5216/322372164.py in run(self)
#      59
#      60                 # Experience ReplayでQ関数を更新する
# ---> 61                 self.agent.update_q_function()
#      62
#      63                 # 観測の更新
#
# /var/folders/jm/3cgjkcw943s630kp7txh0rpw0000gq/T/ipykernel_5216/792763525.py in update_q_function(self)
#       9     def update_q_function(self):
#      10         '''Q関数を更新する'''
# ---> 11         self.brain.replay()
#      12
#      13     def get_action(self, state, episode):
#
# /var/folders/jm/3cgjkcw943s630kp7txh0rpw0000gq/T/ipykernel_5216/3076239057.py in replay(self)
#      42
#      43         # 4. 結合パラメータの更新
# ---> 44         self.update_main_q_network()
#      45
#      46     def decide_action(self, state, episode):
#
# /var/folders/jm/3cgjkcw943s630kp7txh0rpw0000gq/T/ipykernel_5216/3076239057.py in update_main_q_network(self)
#     145         # 4.3 結合パラメータを更新する
#     146         self.optimizer.zero_grad()  # 勾配をリセット
# --> 147         loss.backward()  # バックプロパゲーションを計算
#     148         self.optimizer.step()  # 結合パラメータを更新
#     149
#
# /usr/local/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:
